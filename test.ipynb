# %%
import pandas as pd
import json



# Ruta del archivo .jsonl
file_path = ""

# Lista para almacenar los datos normalizados
data = []

# Leer y desanidar cada línea
with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        record = json.loads(line)
        normalized = pd.json_normalize(record)
        data.append(normalized)

# Concatenar todas las filas en un solo DataFrame
df = pd.concat(data, ignore_index=True)

# Mostrar las primeras columnas como ejemplo
print(df.columns.tolist())
print(df.head())
# Out:
# C:\Users\ntlg2\AppData\Local\Temp\ipykernel_4888\1615572190.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(data, ignore_index=True)
# ...

# %%
df.head()
# Out:
#              warranty sub_status condition seller_contact deal_ids  \
# 0                None         []       new           None       []
# 1  NUESTRA REPUTACION         []      used           None       []
# 2                None         []      used           None       []
# 3                None         []       new           None       []
# 4      MI REPUTACION.         []      used           None       []
#
#    base_price                   non_mercado_pago_payment_methods  seller_id  \
# 0        80.0  [{'description': 'Transferencia bancaria', 'id...   74952096
# 1      2650.0  [{'description': 'Transferencia bancaria', 'id...   42093335
# 2        60.0  [{'description': 'Transferencia bancaria', 'id...  133384258
# 3       580.0  [{'description': 'Transferencia bancaria', 'id...  143001605
# 4        30.0  [{'description': 'Transferencia bancaria', 'id...   96873449
#
#   variations site_id  ... location.longitude  location.country.name  \
# ...
